# %%
import numpy as np
import pandas as pd

# %%
run = 100

# ---------- allocate ----------
mean_test       = np.zeros(run)
mean_QRGMM      = np.zeros(run)
mean_CWGAN      = np.zeros(run)
mean_Diffusion  = np.zeros(run)
mean_RectFlow   = np.zeros(run)

std_test        = np.zeros(run)
std_QRGMM       = np.zeros(run)
std_CWGAN       = np.zeros(run)
std_Diffusion   = np.zeros(run)
std_RectFlow    = np.zeros(run)

# ---------- loop ----------
for runi in range(run):
    testdf = pd.read_csv(f"./data/testdata/testdata_{runi+1}.csv")
    test_gen_QRGMM = pd.read_csv(f"./data/testdata_QRGMM/testdata_QRGMM_{runi+1}.csv")
    test_gen_CWGAN = pd.read_csv(f"./data/testdata_CWGAN/testdata_CWGAN_{runi+1}.csv")
    test_gen_Diffusion = pd.read_csv(f"./data/testdata_Diffusion/testdata_Diffusion_{runi+1}.csv")
    test_gen_RectFlow  = pd.read_csv(f"./data/testdata_RectFlow/testdata_RectFlow_{runi+1}.csv")

    # ----- mean -----
    mean_test[runi]      = testdf.iloc[:, 10].mean()
    mean_QRGMM[runi]     = test_gen_QRGMM.iloc[:, 0].mean()
    mean_CWGAN[runi]     = test_gen_CWGAN.iloc[:, 2].mean()
    mean_Diffusion[runi] = test_gen_Diffusion.iloc[:, 2].mean()
    mean_RectFlow[runi]  = test_gen_RectFlow.iloc[:, 2].mean()

    # ----- std -----
    std_test[runi]       = testdf.iloc[:, 10].std(ddof=1)
    std_QRGMM[runi]      = test_gen_QRGMM.iloc[:, 0].std(ddof=1)
    std_CWGAN[runi]      = test_gen_CWGAN.iloc[:, 2].std(ddof=1)
    std_Diffusion[runi]  = test_gen_Diffusion.iloc[:, 2].std(ddof=1)
    std_RectFlow[runi]   = test_gen_RectFlow.iloc[:, 2].std(ddof=1)

# %%
summary = pd.DataFrame({
    "mean(mean)": [
        mean_test.mean(),
        mean_QRGMM.mean(),
        mean_CWGAN.mean(),
        mean_Diffusion.mean(),
        mean_RectFlow.mean()
    ],
    "std(mean)": [
        mean_test.std(ddof=1),
        mean_QRGMM.std(ddof=1),
        mean_CWGAN.std(ddof=1),
        mean_Diffusion.std(ddof=1),
        mean_RectFlow.std(ddof=1)
    ],
    "mean(std)": [
        std_test.mean(),
        std_QRGMM.mean(),
        std_CWGAN.mean(),
        std_Diffusion.mean(),
        std_RectFlow.mean()
    ],
    "std(std)": [
        std_test.std(ddof=1),
        std_QRGMM.std(ddof=1),
        std_CWGAN.std(ddof=1),
        std_Diffusion.std(ddof=1),
        std_RectFlow.std(ddof=1)
    ]
}, index=["Truth", "QRGMM", "CWGAN", "Diffusion", "RectFlow"])

print("\nSummary statistics:\n")
print(summary.round(4))
# Out:
# Summary statistics:
#
#            mean(mean)  std(mean)  mean(std)  std(std)
# Truth         -0.0007     0.1056    10.9196    0.1165
# QRGMM         -0.0050     0.1209    10.4025    0.1576
# CWGAN          0.0884     2.3263     9.7939    2.0161
# Diffusion      0.0153     0.3431     9.5797    0.6252
# RectFlow      -0.0081     0.1885     9.4219    0.3306

# %%
df_time = pd.read_csv("./results/timing_all_models.csv")

summary = df_time.groupby("model")[["gen_time"]].agg(['mean', 'std'])

print("\nSummary time:\n")
print(summary)
# Out:
# Summary time:
#
#            gen_time
#                mean       std
# model
# CWGAN      0.202201  0.026954
# Diffusion  0.820699  0.009430
# QRGMM      0.003309  0.000620
# RectFlow   0.758711  0.007452
